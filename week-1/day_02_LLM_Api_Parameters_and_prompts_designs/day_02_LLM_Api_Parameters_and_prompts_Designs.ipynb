# %% [markdown]
# # Day 2: LLM API Parameters & Prompt Designs
# In this notebook, we will learn how to control our local LLM's creativity and request structured outputs.
#
# ## What You'll Learn:
# 1. **Temperature:** Controlling how creative or deterministic (predictable) the AI is.
# 2. **Seed:** specifically for making generation repeatable for the same prompt
# 2. **Structured Formats:** Asking the LLM to format its answers as JSON or Markdown tables.
# 3. **Prompt Templates:** Using simple Python strings to build reusable prompt structures.

# %%
# Import the ollama library to communicate with local models
import ollama

print("Day 2 workspace loaded successfully!")
# Out:
# Day 2 workspace loaded successfully!

# %% [markdown]
# ## What is Temperature?
# **Temperature** is a parameter that controls how creative or random the model's responses are. It usually ranges from `0.0` to `1.0`.
#
# - **Temperature = 0.0 (Deterministic / Predictable):** The model will always choose the most likely words. Use this for tasks that require precision, like code writing, math, or factual lookup.
# - **Temperature = 1.0 (Creative / Random):** The model will take more risks and choose more unusual words. Use this for storytelling, brainstorming, or roleplaying.
#
# Let's test this in Python! We will ask the model to Give me a name for a coffee shop.

# %%
# The starter sentence we want the model to complete
prompt = "Give me 10 unique and unusual names for a coffee shop."

# 1. Low Temperature (0.2) -> Highly predictable
print("Low Temperature (0.2) - Predictable & Safe:")
print("-" * 50)

response_low = ollama.chat(
    model='llama3.2:3b',
    messages=[{'role': 'user', 'content': prompt}],
    options={'temperature': 0.2}   
)
print(response_low.message.content)


print("\n" + "="*60 + "\n")

# 2. High Temperature (1.0) -> Creative & Random
print("High Temperature (1.0) - Creative & Random:")
print("-" * 50)

response_high = ollama.chat(
    model='llama3.2:3b',
    messages=[{'role': 'user', 'content': prompt}],
    options={'temperature': 1.0}
)
print(response_high.message.content)
# Out:
# Low Temperature (0.2) - Predictable & Safe:
# --------------------------------------------------
# Here are 10 unique and unusual names for a coffee shop:
#
# 1. **Brewtopia**: A playful name that evokes a sense of a utopia for coffee lovers.
# 2. **The Daily Grindhouse**: A clever name that pokes fun at the daily routine, while also referencing the coffee grind.
# 3. **The Cozy Cup**: A warm and inviting name that suggests a welcoming atmosphere.
# 4. **Java Joint Revival**: A name that nods to the classic "joint" vibe, while also emphasizing the coffee shop's revival of a bygone era.
# 5. **The Perk Parlor**: A whimsical name that references the caffeine "perk" and the idea of a parlor as a gathering place.
# 6. **The Bean Scene**: A name that highlights the coffee shop's focus on high-quality beans and the idea of a vibrant, trendy atmosphere.
# 7. **The Roost**: A simple, yet effective name that suggests a cozy, welcoming space.
# 8. **The Caffeine Lab**: A name that emphasizes the coffee shop's experimentation with unique flavors and brewing methods.
# 9. **The Brewed Awakening**: A name that references the idea of coffee as a morning pick-me-up, while also suggesting a sense of transformation and awakening.
# 10. **The Cup & Chatter**: A name that emphasizes the social aspect of the coffee shop, while also highlighting the importance of a good cup of coffee.
#
# I hope these suggestions inspire you to find the perfect name for your coffee shop!
#
# ============================================================
#
# High Temperature (1.0) - Creative & Random:
# --------------------------------------------------
# Here are 10 unique and unusual names for a coffee shop:
#
# 1. **Brewed Awakening**: This name plays on the idea of coffee being a morning pick-me-up, but also hints at the idea of being awakened to new possibilities.
# 2. **The Coalesce**: This name suggests the coming together of people and flavors, which is perfect for a coffee shop where people can gather and enjoy a cup of coffee.
# 3. **Froth & Co.**: This name highlights the art of frothing milk, which is an essential part of many coffee drinks.
# 4. **The Daily Grind**: This name has a playful, tongue-in-cheek tone, while also acknowledging the daily routine of stopping by a coffee shop.
# 5. **Bean Scene**: This name is a clever play on words, referencing both the coffee beans used to make coffee and the idea of a "scene" or gathering place.
# 6. **The Percolate**: This name references the process of percolating coffee, but also has a fun, energetic vibe to it.
# 7. **Café Cadence**: This name suggests a sense of rhythm and flow, which is perfect for a coffee shop where people can come to enjoy a cup of coffee and connect with others.
# 8. **The Roost**: This name has a cozy, welcoming tone, suggesting a place where people can gather and feel at home.
# 9. **The Coffee Crypt**: This name has a fun, mysterious vibe to it, suggesting a place where people can come to discover new and exciting coffee flavors.
# 10. **The Buzzing Bean**: This name references the buzz of energy and activity that comes with drinking coffee, while also highlighting the coffee beans that make it all possible.
#
# I hope these ideas inspire you to find the perfect name for your coffee shop!

# %% [markdown]
# Temperature controls randomness in token selection, not creativity directly. Lower temperature favors high-probability tokens; higher temperature gives lower-probability tokens a greater chance of being selected.

# %%
prompt = "Give me 1 unique and unusual name for a coffee shop."

for i in range(3):
    response = ollama.chat(
        model="llama3.2:3b",
        messages=[{"role": "user", "content": prompt}],
        options={
            "temperature": 0.2,
            "seed": 42,  # Optional: Set a seed for reproducibility
        },
    )

    print(response.message.content)
# Out:
# Here's a unique and unusual name for a coffee shop:
#
# "Ember & Oak"
#
# This name combines the warm, glowing associations of "Ember" (a glowing coal or piece of hot coal) with the natural, earthy feel of "Oak" (a type of tree). The contrast between the fiery, energetic vibe of "Ember" and the sturdy, grounded feel of "Oak" creates a fascinating and memorable name that could work well for a coffee shop that wants to stand out from the crowd.
# Here's a unique and unusual name for a coffee shop:
#
# "Ember & Oak"
#
# This name combines the warm, glowing associations of "Ember" (a glowing coal or spark) with the natural, earthy feel of "Oak" (a type of tree). The contrast between the fiery, energetic vibe of "Ember" and the sturdy, grounding quality of "Oak" creates a intriguing and memorable name that could appeal to customers looking for a distinctive coffee shop experience.
# Here's a unique and unusual name for a coffee shop:
#
# "Ember & Oak"
#
# This name combines the warm, glowing associations of "Ember" (a glowing coal or spark) with the natural, earthy feel of "Oak" (a type of tree). The contrast between the fiery, energetic vibe of "Ember" and the sturdy, grounding quality of "Oak" creates a intriguing and memorable name that could appeal to customers looking for a distinctive coffee shop experience.

# %% [markdown]
# A seed initializes the random number generator, allowing us to reproduce model outputs when the other generation settings and conditions remain the same.

# %% [markdown]
# ## Requesting Structured Formats (JSON)
# Often, we need the LLM to extract data and return it in a format our code can read.
#
# **JSON (JavaScript Object Notation)** is the industry-standard format for data exchange. It represents data as key-value pairs (very similar to Python dictionaries).
#
# To get clean JSON from an LLM:
# 1. We ask the model to format its output as JSON in our prompt instructions.
# 2. In Ollama, we can also pass `'format': 'json'` in the API call options to force the model to only output valid JSON.

# %%
import json

# Standard text we want to extract information from
raw_text = "Apple Inc. was founded by Steve Jobs in 1976 in Cupertino, California."

# Simple prompt asking the model to extract and return ONLY JSON
prompt = f"""
Extract the company name, founder, and year founded from the text below.
Return the result as a JSON object with these keys: company, founder, year.

Text: "{raw_text}"
"""

print("Requesting JSON extraction...")

# Call the model, forcing it to output valid JSON format
response = ollama.chat(
    model='llama3.2:3b',
    messages=[{'role': 'user', 'content': prompt}],
    format='json'  # This option tells Ollama to guarantee a valid JSON response!
)

raw_reply = response.message.content
print("\Raw Response from AI:")
print(raw_reply)

# ------------------------------------------------------------
# Parse the JSON in Python so we can use it!
# ------------------------------------------------------------
print("\Loading the response in Python:")
try:
    # Convert the string response into a Python dictionary
    data = json.loads(raw_reply)
    
    # Access keys inside the dictionary just like regular Python code
    print(f"Company Name: {data['company']}")
    print(f"Founder:      {data['founder']}")
    print(f"Year:         {data['year']}")
    
except json.JSONDecodeError as e:
    print(f"Failed to parse JSON: {e}")
# Out:
# Requesting JSON extraction...
# \Raw Response from AI:
# {"company": "Apple Inc.", "founder": "Steve Jobs", "year": "1976"}
# \Loading the response in Python:
# Company Name: Apple Inc.
# Founder:      Steve Jobs
# Year:         1976

# %% [markdown]
# ## Reusable Prompt Templates
# Instead of copy-pasting the same instructions every time, we define a blueprint template string.
#
# We use Python placeholders like `{topic}` or `{style}` inside our prompt. Then, we use `.format()` to plug in different values dynamically.
#
# This makes our code highly reusable and clean.

# %%
# 1. Define a template prompt with placeholders {language} and {phrase}
translation_template = """
Translate the following phrase into {language}. 
Provide ONLY the translated words and nothing else.

Phrase: "{phrase}"
"""

# 2. Let's write a simple helper function that fills the template and calls Ollama
def translate_phrase(target_language, input_phrase):
    # Fill in the placeholders in our template
    filled_prompt = translation_template.format(
        language=target_language,
        phrase=input_phrase
    )
    
    # Send the filled prompt to Ollama
    response = ollama.chat(
        model='llama3.2:3b',
        messages=[{'role': 'user', 'content': filled_prompt}]
    )
    
    # Return the translation text
    return response.message.content.strip()

# ------------------------------------------------------------
# 3. Test our template with different inputs!
# ------------------------------------------------------------
phrase_to_translate = "Hello, how are you today?"

# Test Hindi
hindi_result = translate_phrase(target_language="Hindi", input_phrase=phrase_to_translate)
print(f"\nHindi translation: {hindi_result}")

# Test Gujarati
gujarati_result = translate_phrase(target_language="Gujarati", input_phrase=phrase_to_translate)
print(f"\nGujarati translation: {gujarati_result}")

# Test Panjabi
panjabi_result = translate_phrase(target_language="Panjabi", input_phrase=phrase_to_translate)
print(f"\nPanjabi translation: {panjabi_result}")
# Out:
# Hindi translation: नमस्ते, क्या आप आज कैसे हैं?
#
# Gujarati translation: હલો, આપણે આજ કેમ છીએ?
#
# Panjabi translation: "ਨਮਸਤੇ, ਤੁਸੀਂ ਕਿਵੇਂ ਹੋ?"
#
# 1. Namaste
# 2. Tusien
# 3. Kivayen
# 4. Ho
